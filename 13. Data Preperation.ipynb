# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Hemanthkaruturi/python_for_datascience/master/data/Financial%20Sample.csv')

# %%
df.head()
# Out:
#       Segment  Country        Place  ... Month Number   Month Name   Year
# 0  Government   Canada   Carretera   ...            1      January   2014
# 1  Government  Germany   Carretera   ...            1      January   2014
# 2   Midmarket   France   Carretera   ...            6         June   2014
# 3   Midmarket  Germany   Carretera   ...            6         June   2014
# 4   Midmarket   Mexico   Carretera   ...            6         June   2014
#
# [5 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['Segment', 'Country', 'Place', ' Discount Band ', 'Units Sold',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
#df[' Profit ']

# %%
s = ' test '

# %%
s.strip()
# Out:
# 'test'

# %%
def strip_space(s):
  return s.strip()

# %%
l = ['One', ' Two ']

# %%
list(map(strip_space, l))
# Out:
# ['One', 'Two']

# %%
l1 = []
for i in l:
  l1.append(strip_space(i))

# %%
l1
# Out:
# ['One', 'Two']

# %%
df.columns = list(map(strip_space, df.columns ))

# %%
df.columns[0] = 'Segments'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-964ed28a8666> in <module>()
# ----> 1 df.columns[0] = 'Segments'
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    4082
#    4083     def __setitem__(self, key, value):
# -> 4084         raise TypeError("Index does not support mutable operations")
#    4085
#    4086     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.columns
# Out:
# Index(['Segment', 'Country', 'Place', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %%
l = list(df.columns)

# %%
l[0] = 'Segments'

# %%
l
# Out:
# ['Segments',
#  'Country',
#  'Place',
#  'Discount Band',
#  'Units Sold',
#  'Manufacturing Price',
#  'Sale Price',
#  'Gross Sales',
#  'Discounts',
#  'Sales',
#  'COGS',
#  'Profit',
#  'Date',
#  'Month Number',
#  'Month Name',
#  'Year']

# %%
# df.columns = l

# %%
# best way
df.rename(columns={'Segment':'Segments'}, inplace=True)

# %%
df.head()
# Out:
#      Segments  Country        Place  ... Month Number  Month Name  Year
# 0  Government   Canada   Carretera   ...            1    January   2014
# 1  Government  Germany   Carretera   ...            1    January   2014
# 2   Midmarket   France   Carretera   ...            6       June   2014
# 3   Midmarket  Germany   Carretera   ...            6       June   2014
# 4   Midmarket   Mexico   Carretera   ...            6       June   2014
#
# [5 rows x 16 columns]

# %%
df.describe()
# Out:
#         Units Sold  Month Number         Year
# count   700.000000    700.000000   700.000000
# mean   1608.294286      7.900000  2013.750000
# std     867.427859      3.377321     0.433322
# min     200.000000      1.000000  2013.000000
# 25%     905.000000      5.750000  2013.750000
# 50%    1542.500000      9.000000  2014.000000
# 75%    2229.125000     10.250000  2014.000000
# max    4492.500000     12.000000  2014.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segments             700 non-null    object
#  1   Country              700 non-null    object
#  2   Place                700 non-null    object
#  3   Discount Band        700 non-null    object
#  4   Units Sold           700 non-null    float64
#  5   Manufacturing Price  700 non-null    object
#  6   Sale Price           700 non-null    object
#  7   Gross Sales          700 non-null    object
#  8   Discounts            700 non-null    object
#  9   Sales                700 non-null    object
#  10  COGS                 700 non-null    object
#  11  Profit               700 non-null    object
#  12  Date                 700 non-null    object
#  13  Month Number         700 non-null    int64
#  14  Month Name           700 non-null    object
#  15  Year                 700 non-null    int64
# dtypes: float64(1), int64(2), object(13)
# memory usage: 87.6+ KB

# %%
df.shape
# Out:
# (700, 16)

# %%
df.shape[0]
# Out:
# 700

# %%
df.shape[1]
# Out:
# 16

# %%
df.ndim
# Out:
# 2

# %%
df.tail()
# Out:
#              Segments                   Country  ...  Month Name  Year
# 695    Small Business                    France  ...      March   2014
# 696    Small Business                    Mexico  ...    October   2014
# 697        Government                    Mexico  ...   February   2014
# 698        Government                    Canada  ...      April   2014
# 699  Channel Partners  United States of America  ...        May   2014
#
# [5 rows x 16 columns]

# %%
df['Manufacturing Price'].head()
# Out:
# 0     $3.00
# 1     $3.00
# 2     $3.00
# 3     $3.00
# 4     $3.00
# Name: Manufacturing Price, dtype: object

# %%
df['Manufacturing Price'].unique()
# Out:
# array([' $3.00 ', ' $5.00 ', ' $10.00 ', ' $120.00 ', ' $250.00 ',
#        ' $260.00 '], dtype=object)

# %%
s = '$3'
s.replace('$','')
# Out:
# '3'

# %%
df['Manufacturing Price'] = df['Manufacturing Price'].str.replace('$','')

# %%
df['Manufacturing Price'].unique()
# Out:
# array([' 3.00 ', ' 5.00 ', ' 10.00 ', ' 120.00 ', ' 250.00 ', ' 260.00 '],
#       dtype=object)

# %%
df['Manufacturing Price'] = df['Manufacturing Price'].str.strip()

# %%
df['Manufacturing Price'].unique()
# Out:
# array(['3.00', '5.00', '10.00', '120.00', '250.00', '260.00'],
#       dtype=object)

# %%
df['Manufacturing Price'] = df['Manufacturing Price'].astype('float')

# %%
df.dtypes
# Out:
# Segments                object
# Country                 object
# Place                   object
# Discount Band           object
# Units Sold             float64
# Manufacturing Price    float64
# Sale Price              object
# Gross Sales             object
# Discounts               object
# Sales                   object
# COGS                    object
# Profit                  object
# Date                    object
# Month Number             int64
# Month Name              object
# Year                     int64
# dtype: object

# %%
columns = ['Sale Price', 'Gross Sales', 'Discounts', 'Sales', 'COGS', 'Profit']

# %%
def remove_characters(column, rm_character):

  df[column] = df[column].str.replace(rm_character,'')

  return df[column]

# %%
for column in columns:
  df[column] = remove_characters(column, '$')
  df[column] = remove_characters(column, ',')
  df[column] = remove_characters(column, '(')
  df[column] = remove_characters(column, ')')

# %%
df.head()
# Out:
#      Segments  Country        Place  ... Month Number  Month Name  Year
# 0  Government   Canada   Carretera   ...            1    January   2014
# 1  Government  Germany   Carretera   ...            1    January   2014
# 2   Midmarket   France   Carretera   ...            6       June   2014
# 3   Midmarket  Germany   Carretera   ...            6       June   2014
# 4   Midmarket   Mexico   Carretera   ...            6       June   2014
#
# [5 rows x 16 columns]

# %%
df['Sale Price'].unique()
# Out:
# array([' 20.00 ', ' 15.00 ', ' 350.00 ', ' 12.00 ', ' 125.00 ',
#        ' 300.00 ', ' 7.00 '], dtype=object)

# %%
df['Sale Price']  = df['Sale Price'].astype('float')
# Out:
# 0       20.0
#        ' 2936.08 ', ' 274.40 ', ' 287.14 ', ' 583.80 ', ' 6798.40 ',
#        ' 3710.70 ', ' 2340.24 ', ' 3385.20 ', ' 33642.00 ', ' 17902.50 ',
#        ' 62832.00 ', ' 42420.00 ', ' 3177.30 ', ' 4830.00 ', ' 49367.50 ',
#        ' 109147.50 ', ' 58751.00 ', ' 9800.00 ', ' 380.24 ', ' 1692.46 ',
#        ' 728.00 ', ' 5187.00 ', ' 3660.30 ', ' 4895.52 ', ' 1696.38 ',
#        ' 34300.00 ', ' 3732.96 ', ' 57673.00 ', ' 94178.00 ',
#        ' 27562.50 ', ' 1696.80 ', ' 103320.00 ', ' 11298.00 ',
#        ' 106512.00 ', ' 2844.94 ', ' 106722.00 ', ' 62769.00 ',
#        ' 37296.00 ', ' 49770.00 ', ' 4158.00 ', ' 3927.00 ', ' 22012.50 ',
#        ' 51881.25 ', ' 20343.75 ', ' 24570.00 ', ' 3474.00 ', ' 3631.50 ',
#        ' 2661.75 ', ' 149677.50 ', ' 5757.75 ', ' 801.00 ', ' 2643.75 ',
#        ' 105367.50 ', ' 112927.50 ', ' 1645.20 ', ' 879.00 ', ' 900.00 ',
#        ' 6358.50 ', ' 12431.25 ', ' 115830.00 ', ' 45712.50 ',
#        ' 2596.50 ', ' 1107.00 ', ' 55387.50 ', ' 10350.00 ',
#        ' 111375.00 ', ' 1436.40 ', ' 759.15 ', ' 3250.80 '], dtype=object)

# %%
df['Discounts'].str.replace('-','0')
# Out:
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
#           ...
# 695     111375.00
# 696      24570.00
# 697       1436.40
# 698        759.15
# 699       3250.80
# Name: Discounts, Length: 700, dtype: object

# %%
df.dtypes
# Out:
# Segments                object
# Country                 object
# Place                   object
# Discount Band           object
# Units Sold             float64
# Manufacturing Price    float64
# Sale Price              object
# Gross Sales             object
# Discounts               object
# Sales                   object
# COGS                    object
# Profit                  object
# Date                    object
# Month Number             int64
# Month Name              object
# Year                     int64
# dtype: object

# %%
df.head()
# Out:
#      Segments  Country        Place  ... Month Number  Month Name  Year
# 0  Government   Canada   Carretera   ...            1    January   2014
# 1  Government  Germany   Carretera   ...            1    January   2014
# 2   Midmarket   France   Carretera   ...            6       June   2014
# 3   Midmarket  Germany   Carretera   ...            6       June   2014
# 4   Midmarket   Mexico   Carretera   ...            6       June   2014
#
# [5 rows x 16 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')

# %%
df['Date'].dt.month
# Out:
# 0       1
# 1       1
# 2       6
# 3       6
# 4       6
#        ..
# 695     3
# 696    10
# 697     2
# 698     4
# 699     5
# Name: Date, Length: 700, dtype: int64

# %%
df['Date'].dt.month_name()
# Out:
# 0       January
# 1       January
# 2          June
# 3          June
# 4          June
#          ...
# 695       March
# 696     October
# 697    February
# 698       April
# 699         May
# Name: Date, Length: 700, dtype: object

# %%
df['Date'].dt.year
# Out:
# 0      2014
# 1      2014
# 2      2014
# 3      2014
# 4      2014
#        ...
# 695    2014
# 696    2014
# 697    2014
# 698    2014
# 699    2014
# Name: Date, Length: 700, dtype: int64

# %%
df['Date'].dt.dayofweek
# Out:
# 0      2
# 1      2
# 2      6
# 3      6
# 4      6
#       ..
# 695    5
# 696    2
# 697    5
# 698    1
# 699    3
# Name: Date, Length: 700, dtype: int64

# %%
df['Date'].dt.day_name()
# Out:
# 0      Wednesday
# 1      Wednesday
# 2         Sunday
# 3         Sunday
# 4         Sunday
#          ...
# 695     Saturday
# 696    Wednesday
# 697     Saturday
# 698      Tuesday
# 699     Thursday
# Name: Date, Length: 700, dtype: object

# %%
df.head()
# Out:
#      Segments  Country        Place  ... Month Number  Month Name  Year
# 0  Government   Canada   Carretera   ...            1    January   2014
# 1  Government  Germany   Carretera   ...            1    January   2014
# 2   Midmarket   France   Carretera   ...            6       June   2014
# 3   Midmarket  Germany   Carretera   ...            6       June   2014
# 4   Midmarket   Mexico   Carretera   ...            6       June   2014
#
# [5 rows x 16 columns]

# %%
df['Segments'].unique()
# Out:
# array(['Government', 'Midmarket', 'Channel Partners', 'Enterprise',
#        'Small Business'], dtype=object)

# %%
df['Segments'].value_counts()
# Out:
# Government          300
# Midmarket           100
# Channel Partners    100
# Small Business      100
# Enterprise          100
# Name: Segments, dtype: int64

# %%
segment_dict = {'Government':1, 'Midmarket':2, 'Channel Partners':3, 'Enterprise':4, 'Small Business':5}

# %%
df.columns
# Out:
# Index(['Segment', 'Country', 'Place', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %%
pd.crosstab(df['Segment'], df['Country'])
# Out:
# Country           Canada  France  Germany  Mexico  United States of America
# Segment
# Channel Partners      20      20       20      20                        20
# Enterprise            20      20       20      20                        20
# Government            60      60       60      60                        60
# Midmarket             20      20       20      20                        20
# Small Business        20      20       20      20                        20

# %%
df['Segments'].map(segment_dict)
# Out:
# 0      1
# 1      1
# 2      2
# 3      2
# 4      2
#       ..
# 695    5
# 696    5
# 697    1
# 698    1
# 699    3
# Name: Segments, Length: 700, dtype: int64

# %%
def multiply(x):
  return x*x

# %%
df['Manufacturing Price'].apply(multiply)
# Out:
# 0          9.0
# 1          9.0
# 2          9.0
# 3          9.0
# 4          9.0
#         ...
# 695    67600.0
# 696    67600.0
# 697       25.0
# 698      100.0
# 699    62500.0
# Name: Manufacturing Price, Length: 700, dtype: float64

# %%
df['Profit'].unique()
# Out:
# array([' 16185.00 ', ' 13210.00 ', ' 10890.00 ', ' 4440.00 ',
#        ' 12350.00 ', ' 136170.00 ', ' 4605.00 ', ' 22662.00 ',
#        ' 18990.00 ', ' 13905.00 ', ' 13327.50 ', ' 47900.00 ',
#        ' 4292.00 ', ' 1725.00 ', ' 3075.00 ', ' 2920.00 ', ' 4870.00 ',
#        ' 90540.00 ', ' 3303.00 ', ' 1766.00 ', ' 2745.00 ', ' 39400.00 ',
#        ' 12360.00 ', ' 2286.00 ', ' 155250.00 ', ' 8208.00 ',
#        ' 10760.00 ', ' 18170.00 ', ' 2986.00 ', ' 9020.00 ', ' 19449.00 ',
#        ' 14105.00 ', ' 100050.00 ', ' 25542.00 ', ' 137430.00 ',
#        ' 18568.80 ', ' 12549.60 ', ' 3055.92 ', ' 285.60 ', ' 298.86 ',
#        ' 806.20 ', ' 17481.60 ', ' 5124.30 ', ' 10196.76 ', ' 14749.80 ',
#        ' 6408.00 ', ' 12787.50', ' 11968.00 ', ' 8080.00 ', ' 4387.70 ',
#        ' 6670.00 ', ' 35262.50', ' 91327.50 ', ' 49159.00 ', ' 8200.00 ',
#        ' 395.76 ', ' 1761.54 ', ' 1872.00 ', ' 7163.00 ', ' 5054.70 ',
#        ' 21330.48 ', ' 1765.62 ', ' 28700.00 ', ' 16265.04 ',
#        ' 48257.00 ', ' 78802.00 ', ' 19687.50', ' 4363.20 ', ' 19680.00 ',
#        ' 2152.00 ', ' 20288.00 ', ' 2961.06 ', ' 20328.00 ', ' 52521.00 ',
#        ' 7104.00 ', ' 35550.00', ' 18117.00 ', ' 5423.00 ', ' 16142.50',
#        ' 38046.25', ' 14918.75', ' 2730.00 ', ' 8106.00 ', ' 4438.50 ',
#        ' 2408.25 ', ' 106912.50 ', ' 7037.25 ', ' 1869.00 ', ' 3231.25 ',
#        ' 75262.50 ', ' 80662.50 ', ' 6580.80 ', ' 2051.00 ', ' 3600.00 ',
#        ' 7771.50 ', ' 9116.25', ' 12870.00 ', ' 33522.50', ' 6058.50 ',
#        ' 1353.00 ', ' 40617.50', ' 7590.00', ' 12375.00 ', ' 1299.60 ',
#        ' 686.85 ', ' 13003.20 '], dtype=object)

# %%
def str_strip(s):
  return s.strip()

# %%
df['Profit'].apply(str_strip)
# Out:
# 0      16185.00
# 1      13210.00
# 2      10890.00
# 3       4440.00
# 4      12350.00
#          ...
# 695    12375.00
# 696     2730.00
# 697     1299.60
# 698      686.85
# 699    13003.20
# Name: Profit, Length: 700, dtype: object

# %%
df['Country'].unique()
# Out:
# array(['Canada', 'Germany', 'France', 'Mexico',
#        'United States of America'], dtype=object)

# %%
df['Country'] = df['Country'].astype('category')

# %%
df['Country'].cat.codes
# Out:
# 0      0
# 1      2
# 2      1
# 3      2
# 4      3
#       ..
# 695    1
# 696    3
# 697    3
# 698    0
# 699    4
# Length: 700, dtype: int8

# %%
# groupby
# joins
# sqldf
# drop duplicates
# melt
# pivot tables

# %% [markdown]
# ## Groupby

# %%
df.dtypes
# Out:
# Segment                 object
# Country                 object
# Place                   object
# Discount Band           object
# Units Sold             float64
# Manufacturing Price    float64
# Sale Price              object
# Gross Sales             object
# Discounts               object
# Sales                   object
# COGS                    object
# Profit                  object
# Date                    object
# Month Number             int64
# Month Name              object
# Year                     int64
# dtype: object

# %%
df[['Segment','Units Sold']]
# Out:
#               Segment  Units Sold
# 0          Government      1618.5
# 1          Government      1321.0
# 2           Midmarket      2178.0
# 3           Midmarket       888.0
# 4           Midmarket      2470.0
# ..                ...         ...
# 695    Small Business      2475.0
# 696    Small Business       546.0
# 697        Government      1368.0
# 698        Government       723.0
# 699  Channel Partners      1806.0
#
# [700 rows x 2 columns]

# %%
df[['Segment','Units Sold']].groupby('Segment').sum()
# Out:
#                   Units Sold
# Segment
# Channel Partners    161263.5
# Enterprise          168552.0
# Government          470673.5
# Midmarket           172178.0
# Small Business      153139.0

# %%
df[['Segment','Units Sold']].groupby('Segment').mean()
# Out:
#                    Units Sold
# Segment
# Channel Partners  1612.635000
# Enterprise        1685.520000
# Government        1568.911667
# Midmarket         1721.780000
# Small Business    1531.390000

# %%
df[['Segment','Country','Units Sold']]
# Out:
#               Segment                   Country  Units Sold
# 0          Government                    Canada      1618.5
# 1          Government                   Germany      1321.0
# 2           Midmarket                    France      2178.0
# 3           Midmarket                   Germany       888.0
# 4           Midmarket                    Mexico      2470.0
# ..                ...                       ...         ...
# 695    Small Business                    France      2475.0
# 696    Small Business                    Mexico       546.0
# 697        Government                    Mexico      1368.0
# 698        Government                    Canada       723.0
# 699  Channel Partners  United States of America      1806.0
#
# [700 rows x 3 columns]

# %%
df[['Segment','Country','Units Sold']].groupby(['Segment','Country']).sum()
# Out:
#                                            Units Sold
# Segment          Country
# Channel Partners Canada                       44062.0
#                  France                       33503.0
#                  Germany                      29689.0
#                  Mexico                       21163.0
#                  United States of America     32846.5
# Enterprise       Canada                       34075.0
#                  France                       33222.0
#                  Germany                      34902.5
#                  Mexico                       28638.0
#                  United States of America     37714.5
# Government       Canada                       98412.0
#                  France                      104724.5
#                  Germany                      89080.0
#                  Mexico                       91750.0
#                  United States of America     86707.0
# Midmarket        Canada                       37772.5
#                  France                       42926.0
#                  Germany                      21599.0
#                  Mexico                       36059.0
#                  United States of America     33821.5
# Small Business   Canada                       33107.0
#                  France                       26555.5
#                  Germany                      26223.5
#                  Mexico                       25715.0
#                  United States of America     41538.0

# %%
segment_units = df[['Segment','Units Sold']].groupby('Segment').mean()

# %%
segment_units
# Out:
#                    Units Sold
# Segment
# Channel Partners  1612.635000
# Enterprise        1685.520000
# Government        1568.911667
# Midmarket         1721.780000
# Small Business    1531.390000

# %%
segment_units.columns
# Out:
# Index(['Units Sold'], dtype='object')

# %%
segment_units.index
# Out:
# Index(['Channel Partners', 'Enterprise', 'Government', 'Midmarket',
#        'Small Business'],
#       dtype='object', name='Segment')

# %%
segment_units = segment_units.reset_index()

# %%
segment_units.columns
# Out:
# Index(['Segment', 'Units Sold'], dtype='object')

# %%
segment_units['Segment']
# Out:
# 0    Channel Partners
# 1          Enterprise
# 2          Government
# 3           Midmarket
# 4      Small Business
# Name: Segment, dtype: object

# %%
df_group = df[['Segment','Country','Units Sold']].groupby(['Segment','Country']).sum()

# %%
df_group.index
# Out:
# MultiIndex([('Channel Partners',                   'Canada'),
#             ('Channel Partners',                   'France'),
#             ('Channel Partners',                  'Germany'),
#             ('Channel Partners',                   'Mexico'),
#             ('Channel Partners', 'United States of America'),
#             (      'Enterprise',                   'Canada'),
#             (      'Enterprise',                   'France'),
#             (      'Enterprise',                  'Germany'),
#             (      'Enterprise',                   'Mexico'),
#             (      'Enterprise', 'United States of America'),
#             (      'Government',                   'Canada'),
#             (      'Government',                   'France'),
#             (      'Government',                  'Germany'),
#             (      'Government',                   'Mexico'),
#             (      'Government', 'United States of America'),
#             (       'Midmarket',                   'Canada'),
#             (       'Midmarket',                   'France'),
#             (       'Midmarket',                  'Germany'),
#             (       'Midmarket',                   'Mexico'),
#             (       'Midmarket', 'United States of America'),
#             (  'Small Business',                   'Canada'),
#             (  'Small Business',                   'France'),
#             (  'Small Business',                  'Germany'),
#             (  'Small Business',                   'Mexico'),
#             (  'Small Business', 'United States of America')],
#            names=['Segment', 'Country'])

# %%
df_group = df_group.reset_index()

# %%
df_group.head()
# Out:
#             Segment                   Country  Units Sold
# 0  Channel Partners                    Canada     44062.0
# 1  Channel Partners                    France     33503.0
# 2  Channel Partners                   Germany     29689.0
# 3  Channel Partners                    Mexico     21163.0
# 4  Channel Partners  United States of America     32846.5

# %% [markdown]
# ## Joins

# %%
Emp_details = {'ID':[1,2,3,4,5,6], 'Name':['Raju', 'Ravi', 'Raghav', 'Ramu', 'Lavanya', 'Ramesh']}
Emp_salary = {'ID':[1,2,3,4,5], 'Salary':[123,545,245,234,234]}

# %%
Emp_details_df = pd.DataFrame(Emp_details)
Emp_salary_df = pd.DataFrame(Emp_salary)

# %%
Emp_details_df
# Out:
#    ID     Name
# 0   1     Raju
# 1   2     Ravi
# 2   3   Raghav
# 3   4     Ramu
# 4   5  Lavanya
# 5   6   Ramesh

# %%
pd.merge(Emp_details_df, Emp_salary_df, how='left')
# Out:
#    ID     Name  Salary
# 0   1     Raju   123.0
# 1   2     Ravi   545.0
# 2   3   Raghav   245.0
# 3   4     Ramu   234.0
# 4   5  Lavanya   234.0
# 5   6   Ramesh     NaN

# %%
pd.merge(Emp_details_df, Emp_salary_df, left_on='ID',right_on='ID' ,how='left')
# Out:
#    ID     Name  Salary
# 0   1     Raju   123.0
# 1   2     Ravi   545.0
# 2   3   Raghav   245.0
# 3   4     Ramu   234.0
# 4   5  Lavanya   234.0
# 5   6   Ramesh     NaN

# %%
pd.merge(Emp_details_df, Emp_salary_df, left_on='ID',right_on='ID' ,how='inner')
# Out:
#    ID     Name  Salary
# 0   1     Raju     123
# 1   2     Ravi     545
# 2   3   Raghav     245
# 3   4     Ramu     234
# 4   5  Lavanya     234

# %%
# !pip install pandasql
# Out:
# Collecting pandasql
#   Downloading https://files.pythonhosted.org/packages/6b/c4/ee4096ffa2eeeca0c749b26f0371bd26aa5c8b611c43de99a4f86d3de0a7/pandasql-0.7.3.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pandasql) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from pandasql) (1.1.5)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.6/dist-packages (from pandasql) (1.3.23)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->pandasql) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->pandasql) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-cp36-none-any.whl size=26820 sha256=12a233ac5938690359134f35421ef043c9432e7230be4c09b3c242b52fd39c12
#   Stored in directory: /root/.cache/pip/wheels/53/6c/18/b87a2e5fa8a82e9c026311de56210b8d1c01846e18a9607fc9
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %%
from pandasql import sqldf

# %%
whos
# Out:
# Variable         Type         Data/Info
# ---------------------------------------
# Emp_details      dict         n=2
# Emp_details_df   DataFrame       ID     Name\n0   1    <...>  Lavanya\n5   6   Ramesh
# Emp_salary       dict         n=2
# Emp_salary_df    DataFrame       ID  Salary\n0   1     <...> 4     234\n4   5     234
# df               DataFrame                  Segment    <...>\n[700 rows x 16 columns]
# df_group         DataFrame                 Segment     <...>es of America     41538.0
# pd               module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# segment_units    DataFrame                Segment   Uni<...>all Business  1531.390000
# sqldf            function     <function sqldf at 0x7fbebb0a48c8>
# strip_space      function     <function strip_space at 0x7fbec5b1aa60>

# %%
query = 'select * from df limit 4'

# %%
sqldf(query)
# Out:
#       Segment  Country        Place  ... Month Number  Month Name  Year
# 0  Government   Canada   Carretera   ...            1    January   2014
# 1  Government  Germany   Carretera   ...            1    January   2014
# 2   Midmarket   France   Carretera   ...            6       June   2014
# 3   Midmarket  Germany   Carretera   ...            6       June   2014
#
# [4 rows x 16 columns]

# %%
sqldf('select * from Emp_salary_df')
# Out:
#    ID  Salary
# 0   1     123
# 1   2     545
# 2   3     245
# 3   4     234
# 4   5     234

# %%
sqldf('select * from df where Segment = "Government"')
# Out:
#         Segment                   Country  ...   Month Name  Year
# 0    Government                    Canada  ...     January   2014
# 1    Government                   Germany  ...     January   2014
# 2    Government                   Germany  ...    December   2014
# 3    Government                    France  ...        June   2014
# 4    Government                   Germany  ...   September   2014
# ..          ...                       ...  ...          ...   ...
# 295  Government                    Canada  ...        July   2014
# 296  Government  United States of America  ...     October   2013
# 297  Government                    France  ...    December   2014
# 298  Government                    Mexico  ...    February   2014
# 299  Government                    Canada  ...       April   2014
#
# [300 rows x 16 columns]

# %%
sqldf('select * from Emp_details_df as a left join Emp_salary_df as b on a.ID = b.ID')
# Out:
#    ID     Name   ID  Salary
# 0   1     Raju  1.0   123.0
# 1   2     Ravi  2.0   545.0
# 2   3   Raghav  3.0   245.0
# 3   4     Ramu  4.0   234.0
# 4   5  Lavanya  5.0   234.0
# 5   6   Ramesh  NaN     NaN

# %%
df.drop_duplicates()
# Out:
#               Segment                   Country  ...  Month Name  Year
# 0          Government                    Canada  ...    January   2014
# 1          Government                   Germany  ...    January   2014
# 2           Midmarket                    France  ...       June   2014
# 3           Midmarket                   Germany  ...       June   2014
# 4           Midmarket                    Mexico  ...       June   2014
# ..                ...                       ...  ...         ...   ...
# 695    Small Business                    France  ...      March   2014
# 696    Small Business                    Mexico  ...    October   2014
# 697        Government                    Mexico  ...   February   2014
# 698        Government                    Canada  ...      April   2014
# 699  Channel Partners  United States of America  ...        May   2014
#
# [700 rows x 16 columns]

# %%
df.drop_duplicates(subset=['Segment', 'Country', 'Place'])
# Out:
#               Segment  Country        Place  ... Month Number  Month Name  Year
# 0          Government   Canada   Carretera   ...            1    January   2014
# 1          Government  Germany   Carretera   ...            1    January   2014
# 2           Midmarket   France   Carretera   ...            6       June   2014
# 3           Midmarket  Germany   Carretera   ...            6       June   2014
# 4           Midmarket   Mexico   Carretera   ...            6       June   2014
# ..                ...      ...          ...  ...          ...         ...   ...
# 488  Channel Partners   Canada    Amarilla   ...            4      April   2014
# 490  Channel Partners  Germany    Amarilla   ...            8     August   2014
# 493    Small Business   France    Amarilla   ...           12   December   2014
# 534         Midmarket   Mexico    Amarilla   ...           12   December   2014
# 598         Midmarket   France        Velo   ...            1    January   2014
#
# [150 rows x 16 columns]

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Segment, Country, Place, Discount Band, Units Sold, Manufacturing Price, Sale Price, Gross Sales, Discounts, Sales, COGS, Profit, Date, Month Number, Month Name, Year]
# Index: []

# %%
df.T
# Out:
#                               0    ...                       699
# Segment                Government  ...          Channel Partners
# Country                    Canada  ...  United States of America
# Place                  Carretera   ...                      VTT
# Discount Band               None   ...                     High
# Units Sold                 1618.5  ...                      1806
# Manufacturing Price             3  ...                       250
# Sale Price                $20.00   ...                   $12.00
# Gross Sales           $32,370.00   ...               $21,672.00
# Discounts                   $-     ...                $3,250.80
# Sales                 $32,370.00   ...               $18,421.20
# COGS                  $16,185.00   ...                $5,418.00
# Profit                $16,185.00   ...               $13,003.20
# Date                   01-01-2014  ...                01-05-2014
# Month Number                    1  ...                         5
# Month Name               January   ...                      May
# Year                         2014  ...                      2014
#
# [16 rows x 700 columns]

# %%
df.transpose()
# Out:
#                               0    ...                       699
# Segment                Government  ...          Channel Partners
# Country                    Canada  ...  United States of America
# Place                  Carretera   ...                      VTT
# Discount Band               None   ...                     High
# Units Sold                 1618.5  ...                      1806
# Manufacturing Price             3  ...                       250
# Sale Price                $20.00   ...                   $12.00
# Gross Sales           $32,370.00   ...               $21,672.00
# Discounts                   $-     ...                $3,250.80
# Sales                 $32,370.00   ...               $18,421.20
# COGS                  $16,185.00   ...                $5,418.00
# Profit                $16,185.00   ...               $13,003.20
# Date                   01-01-2014  ...                01-05-2014
# Month Number                    1  ...                         5
# Month Name               January   ...                      May
# Year                         2014  ...                      2014
#
# [16 rows x 700 columns]

# %%
# melt
# pivot table (dcast)

# %%
pew = pd.read_csv('https://raw.githubusercontent.com/Hemanthkaruturi/python_for_datascience/master/data/pew.csv')

# %%
pew
# Out:
#                    religion  <$10k  ...  >150k  Don't know/refused
# 0                  Agnostic     27  ...     84                  96
# 1                   Atheist     12  ...     74                  76
# 2                  Buddhist     27  ...     53                  54
# 3                  Catholic    418  ...    633                1489
# 4        Don’t know/refused     15  ...     18                 116
# 5          Evangelical Prot    575  ...    414                1529
# 6                     Hindu      1  ...     54                  37
# 7   Historically Black Prot    228  ...     78                 339
# 8         Jehovah's Witness     20  ...      6                  37
# 9                    Jewish     19  ...    151                 162
# 10            Mainline Prot    289  ...    634                1328
# 11                   Mormon     29  ...     42                  69
# 12                   Muslim      6  ...      6                  22
# 13                 Orthodox     13  ...     46                  73
# 14          Other Christian      9  ...     12                  18
# 15             Other Faiths     20  ...     41                  71
# 16    Other World Religions      5  ...      4                   8
# 17             Unaffiliated    217  ...    258                 597
#
# [18 rows x 11 columns]

# %%
pew.melt(id_vars='religion', var_name='Income', value_name='Count')
# Out:
#                   religion              Income  Count
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
weather = pd.read_csv('weather.csv')

# %%
weather.head()
# Out:
#    Year  Month Element  1    2    3  4    5  6  ...   23 24 25 26 27 28 29   30 31
# 0  2010      1    tmax  .    .    .  .    .  .  ...    .  .  .  .  .  .  .  278  .
# 1  2010      1    tmin  .    .    .  .    .  .  ...    .  .  .  .  .  .  .  145  .
# 2  2010      2    tmax  .  273  241  .    .  .  ...  299  .  .  .  .  .  .    .  .
# 3  2010      2    tmin  .  144  144  .    .  .  ...  107  .  .  .  .  .  .    .  .
# 4  2010      3    tmax  .    .    .  .  321  .  ...    .  .  .  .  .  .  .    .  .
#
# [5 rows x 34 columns]

# %%
columns = range(1,32)
for column in columns:
  weather[str(column)] = weather[str(column)].str.replace('.','0')
  weather[str(column)] = weather[str(column)].str.strip()
  weather[str(column)] = weather[str(column)].astype(int)

# %%
weather.dtypes
# Out:
# Year        int64
# Month       int64
# Element    object
# 1           int64
# 2           int64
# 3           int64
# 4           int64
# 5           int64
# 6           int64
# 7           int64
# 8           int64
# 9           int64
# 10          int64
# 11          int64
# 12          int64
# 13          int64
# 14          int64
# 15          int64
# 16          int64
# 17          int64
# 18          int64
# 19          int64
# 20          int64
# 21          int64
# 22          int64
# 23          int64
# 24          int64
# 25          int64
# 26          int64
# 27          int64
# 28          int64
# 29          int64
# 30          int64
# 31          int64
# dtype: object

# %%
weather_melt = weather.melt(id_vars=['Year',	'Month',	'Element'], var_name='day', value_name='temperature')

# %%
weather_melt
# Out:
#      Year  Month Element day  temperature
# 0    2010      1    tmax   1            0
# 1    2010      1    tmin   1            0
# 2    2010      2    tmax   1            0
# 3    2010      2    tmin   1            0
# 4    2010      3    tmax   1            0
# ..    ...    ...     ...  ..          ...
# 677  2010     10    tmin  31            0
# 678  2010     11    tmax  31            0
# 679  2010     11    tmin  31            0
# 680  2010     12    tmax  31            0
# 681  2010     12    tmin  31            0
#
# [682 rows x 5 columns]

# %%
# Year Month Day tmin tmax

# %%
weather_pivot = pd.pivot_table(data=weather_melt, values='temperature', index=['Year', 'Month', 'day'], columns='Element')

# %%
weather_pivot.columns
# Out:
# Index(['tmax', 'tmin'], dtype='object', name='Element')

# %%
weather_pivot.index
# Out:
# MultiIndex([(2010,  1,  '1'),
#             (2010,  1, '10'),
#             (2010,  1, '11'),
#             (2010,  1, '12'),
#             (2010,  1, '13'),
#             (2010,  1, '14'),
#             (2010,  1, '15'),
#             (2010,  1, '16'),
#             (2010,  1, '17'),
#             (2010,  1, '18'),
#             ...
#             (2010, 12, '29'),
#             (2010, 12,  '3'),
#             (2010, 12, '30'),
#             (2010, 12, '31'),
#             (2010, 12,  '4'),
#             (2010, 12,  '5'),
#             (2010, 12,  '6'),
#             (2010, 12,  '7'),
#             (2010, 12,  '8'),
#             (2010, 12,  '9')],
#            names=['Year', 'Month', 'day'], length=341)

# %%
df = weather_pivot.reset_index()

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'day', 'tmax', 'tmin'], dtype='object', name='Element')

# %%
df
# Out:
# Element  Year  Month day  tmax  tmin
# 0        2010      1   1     0     0
# 1        2010      1  10     0     0
# 2        2010      1  11     0     0
# 3        2010      1  12     0     0
# 4        2010      1  13     0     0
# ..        ...    ...  ..   ...   ...
# 336      2010     12   5     0     0
# 337      2010     12   6   278   105
# 338      2010     12   7     0     0
# 339      2010     12   8     0     0
# 340      2010     12   9     0     0
#
# [341 rows x 5 columns]

# %%
# statists
# supervised
## regression
## classification
# unsupervised
## clustering
# boosting algorithms
