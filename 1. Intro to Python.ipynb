# %%
print("Hello world!")
# Out:
# Hello world!

# %%
# !ls
# Out:
# drive  sample_data

# %%
x = 2

# %%
xy = 4

# %%
int
# Out:
# int

# %%
int = 2

# %%
id(x)
# Out:
# 10914528

# %%
id(2)
# Out:
# 10914528

# %%
y = 2

# %%
id(y)
# Out:
# 10914528

# %%
x = 4

# %%
id(x)
# Out:
# 10914592

# %%
x = 5.5

# %%
id(x)
# Out:
# 139940695190816

# %%
x = 1

# %%
x = 2.2

# %%
x = 2+3j

# %%
s = "Hemanth"

# %%
b = False

# %%
b = True

# %%
s = "Hemanth"

# %%
s[0]
# Out:
# 'H'

# %%
s[6]
# Out:
# 'h'

# %%
s[-1]
# Out:
# 'h'

# %%
s[-7]
# Out:
# 'H'

# %%
s[:3]
# Out:
# 'Hem'

# %%
s[2:5]
# Out:
# 'man'

# %%
s[-3:-6]
# Out:
# ''

# %%
s[-6:-3]
# Out:
# 'ema'

# %%
s[:]
# Out:
# 'Hemanth'

# %%
s[::2]
# Out:
# 'Hmnh'

# %%
s[2:5]
# Out:
# 'man'

# %%
s[2:5:2]
# Out:
# 'mn'

# %%
s[::-1]
# Out:
# 'htnameH'

# %%
s[::-2]
# Out:
# 'hnmH'

# %%
s[2:5:-1]
# Out:
# ''

# %%
s[5:2:-1]
# Out:
# 'tna'

# %%
s = "Hemanth"

# %%
s = s[:4]

# %%
s
# Out:
# 'Hema'

# %%
s[0] = "E"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-9a22f75a53a2> in <module>()
# ----> 1 s[0] = "E"
#
# TypeError: 'str' object does not support item assignment

# %%
s = "Hello"
s1 = "world"

# %%
s + s1
# Out:
# 'Helloworld'

# %%
s * 3
# Out:
# 'HelloHelloHello'

# %%
"Hello" + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-801ea13c8371> in <module>()
# ----> 1 "Hello" + 3
#
# TypeError: must be str, not int

# %%
text = "My name is Hemanth"

# %%
"Hemanth" in text
# Out:
# True

# %%
"Ram" in text
# Out:
# False

# %%
"Ram" not in text
# Out:
# True

# %% [markdown]
# # Built-in functions

# %%
s = "Hemanth"

# %%
s.capitalize()
# Out:
# 'Hemanth'

# %%
s.upper()
# Out:
# 'HEMANTH'

# %%
s
# Out:
# 'Hemanth'

# %%
s = s.upper()

# %%
s
# Out:
# 'HEMANTH'

# %%
s = "Hemanth"
s.lower()
# Out:
# 'hemanth'

# %%
s = " Hemanth "
s.strip()
# Out:
# 'Hemanth'

# %%
s.count('e')
# Out:
# 1

# %%
s.find('e')
# Out:
# 2

# %%
s.isalpha()
# Out:
# False

# %%
len(s)
# Out:
# 9

# %%
s.index('e')
# Out:
# 2

# %%
w = ["M","e","n"]
"".join(w)
# Out:
# 'Men'

# %%
sentence = "This is a sentence"
sentence.split(" ")
# Out:
# ['This', 'is', 'a', 'sentence']

# %% [markdown]
# # Lists

# %%
l = list([1,2,3])

# %%
l = [1,2,3,4]

# %%
l[0]
# Out:
# 1

# %%
l[:3]
# Out:
# [1, 2, 3]

# %%
l[::-1]
# Out:
# [4, 3, 2, 1]

# %%
l[0] = 45

# %%
l
# Out:
# [45, 2, 3, 4]

# %%
l = [1,2.2,3+4j,"Hemanth",True,[3,4,5],int]

# %%
int(2.3)
# Out:
# 2

# %%
l[6](2.3)
# Out:
# 2

# %%
l.append(45)

# %%
l
# Out:
# [1, 2.2, (3+4j), 'Hemanth', True, [3, 4, 5], int, 45]

# %%
l.count(1)
# Out:
# 2

# %%
l.extend([2,3,4])

# %%
l
# Out:
# [1, 2.2, (3+4j), 'Hemanth', True, [3, 4, 5], int, 45, 2, 3, 4]

# %%
l.append([2,3,4])

# %%
l
# Out:
# [1, 2.2, (3+4j), 'Hemanth', True, [3, 4, 5], int, 45, 2, 3, 4, [2, 3, 4]]

# %%
l.insert(0,0)

# %%
l
# Out:
# [0, 1, 2.2, (3+4j), 'Hemanth', True, [3, 4, 5], int, 45, 2, 3, 4, [2, 3, 4]]

# %%
l.insert(0,[2,3,4])

# %%
a = list([1,2,3])
b = [2,3,4]
b.extend(a)

# %%
l1 = l

# %%
l1
# Out:
# [[2, 3, 4],
#  0,
#  1,
#  2.2,
#  (3+4j),
#  'Hemanth',
#  True,
#  [3, 4, 5],
#  int,
#  45,
#  2,
#  3,
#  4,
#  [2, 3, 4]]

# %%
l1.pop(0)
# Out:
# [2, 3, 4]

# %%
l1
# Out:
# [0, 1, 2.2, (3+4j), 'Hemanth', True, [3, 4, 5], int, 45, 2, 3, 4, [2, 3, 4]]

# %%
l
# Out:
# [0, 1, 2.2, (3+4j), 'Hemanth', True, [3, 4, 5], int, 45, 2, 3, 4, [2, 3, 4]]

# %%
l1 = l.copy()

# %%
l1
# Out:
# [0, 1, 2.2, (3+4j), 'Hemanth', True, [3, 4, 5], int, 45, 2, 3, 4, [2, 3, 4]]

# %%
l
# Out:
# [0, 1, 2.2, (3+4j), 'Hemanth', True, [3, 4, 5], int, 45, 2, 3, 4, [2, 3, 4]]

# %%
l1.pop()
# Out:
# [2, 3, 4]

# %%
l1
# Out:
# [0, 1, 2.2, (3+4j), 'Hemanth', True, [3, 4, 5], int, 45, 2, 3, 4]

# %%
l
# Out:
# [0, 1, 2.2, (3+4j), 'Hemanth', True, [3, 4, 5], int, 45, 2, 3, 4, [2, 3, 4]]

# %%
l = [1,2,3,4]

# %%
sum(l)
# Out:
# 10

# %%
len(l)
# Out:
# 4

# %%
min(l)
# Out:
# 1

# %%
max(l)
# Out:
# 4

# %%
w = ["M","e","n"]

# %%
# Out:
# 'M e n'

# %% [markdown]
# # Tuple

# %%
t = (2,3,4)

# %%
t[0]
# Out:
# 2

# %%
t[0] = 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-08a0409f2124> in <module>()
# ----> 1 t[0] = 4
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.count(4)
# Out:
# 1

# %%
t.index(2)
# Out:
# 0

# %%
t = (1)

# %%
t
# Out:
# 1

# %%
t = (1,)

# %%
t = 1,2,3,4

# %%
t
# Out:
# (1, 2, 3, 4)

# %%
t = (1,2,3,[4,5,6])

# %%
t[3]
# Out:
# [4, 5, 6]

# %%
t[3][2] = 7

# %%
t[3].append(4)

# %%
t
# Out:
# (1, 2, 3, [4, 5, 7, 4])

# %% [markdown]
# # sets

# %%
# sets are always unique
# in sets you can not store iteratables
# sets does not have any index

# %%
s = {2,3,4}

# %%
type(s)
# Out:
# set

# %%
s = {2,3,4,4}

# %%
s
# Out:
# {2, 3, 4}

# %%
s = {3,4.4,"Hemanth"}

# %%
s
# Out:
# {3, 4.4, 'Hemanth'}

# %%
s = {3,4.4,"Hemanth", [1,2,3]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-698305a32882> in <module>()
# ----> 1 s = {3,4.4,"Hemanth", [1,2,3]}
#
# TypeError: unhashable type: 'list'

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-c9c96910e542> in <module>()
# ----> 1 s[0]
#
# TypeError: 'set' object does not support indexing

# %%
s = {1,2,3,4,5}
s1 = {4,5,6,7,8}

# %%
s.union(s1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s.intersection(s1)
# Out:
# {4, 5}

# %%
s.difference(s1)
# Out:
# {1, 2, 3}

# %%
s.update(s1)

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
l = [2,3,4,4]

# %%
l = list(set(l))

# %%
l
# Out:
# [2, 3, 4]

# %%
# convert to list
list()
# convert to tuple
tuple()
# convert to set
set()
# Out:
# set()

# %% [markdown]
# # dictionaries

# %%
d = {"Key": "Value"}

# %%
d["Key"]
# Out:
# 'Value'

# %%
d = {"Key1": "Value1", "Key2": "Value2"}

# %%
d["Key2"]
# Out:
# 'Value2'

# %%
# properties of keys
# keys cannot be duplicate
# keys cannot store iteratables
# keys doesnot have index

# %%
d = {"int":1, "float":3.4, "list":[2,3,4,5], "dict":{"Key1":"Value1"}, "set":{1,2,3}, "tuple":(2,3,4)}

# %%
d["list"]
# Out:
# [2, 3, 4, 5]

# %%
d["list"][3] = 6

# %%
d["list"] = [3,4,5]

# %%
del d["list"]

# %%
d
# Out:
# {'dict': {'Key1': 'Value1'},
#  'float': 3.4,
#  'int': 1,
#  'set': {1, 2, 3},
#  'tuple': (2, 3, 4)}

# %%
d["set"]
# Out:
# {1, 2, 3}

# %%
d = {"set":{2,3}, 2:3}

# %%
d[2]
# Out:
# 3

# %%
d = {[1,2,3]:4}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-6450a90c76f5> in <module>()
# ----> 1 d = {[1,2,3]:4}
#
# TypeError: unhashable type: 'list'

# %%
d = {"key1":"Value1", "Key2":"Value2"}

# %%
d.items()
# Out:
# dict_items([('key1', 'Value1'), ('Key2', 'Value2')])

# %%
d.keys()
# Out:
# dict_keys(['key1', 'Key2'])

# %%
d.values()
# Out:
# dict_values(['Value1', 'Value2'])

# %%
# Datatypes
int
float
complex
string
boolean

lists
tuple
sets
dictionary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f2bb968a0cfc> in <module>()
#       3 float
#       4 complex
# ----> 5 string
#       6 boolean
#       7
#
# NameError: name 'string' is not defined

# %% [markdown]
# # Operators

# %%
# 4 %% 2 -> R
4 % 2
# Out:
# 0

# %%
# floor division
6//4
# Out:
# 1

# %%
round(2.6)
# Out:
# 3

# %%
6//3.5
# Out:
# 1.0

# %%
round(6/3.5)
# Out:
# 2

# %%
2**4
# Out:
# 16

# %%
x = 2
y = 3
# x <= 2 & y > 2 --> R
x <= 2 and y > 2
# Out:
# True

# %%
#      421
#2 --> 010
# &
#3 --> 011
      0 1 0

# %%
2 & 3
# Out:
# 2

# %%
x = 5
# x = x+5
x += 5

# %%
x
# Out:
# 10

# %%
x = 2
y = 3
x == y
# Out:
# False

# %%
x is y
# Out:
# False

# %%
x = 1
id(x)
# Out:
# 10914496

# %%
id(1)
# Out:
# 10914496

# %%
x is 1
# Out:
# True

# %%
"Hemanth" in "My name is Hemanth"
# Out:
# True

# %%
1 in [1,2,3]
# Out:
# True

# %%
# print("This is a print statement " 
#       )
# Out:
#   File "<ipython-input-35-1b931f2be176>", line 1
#     print("This is a print statement " \
#                                          ^
# SyntaxError: unexpected character after line continuation character

# %%
""" Somenthing """
# Out:
# ' Somenthing '

# %%
# comments
# multiple comments ctrl + /
