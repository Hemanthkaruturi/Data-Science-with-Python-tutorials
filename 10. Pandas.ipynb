# %%
import array
array.array('i', [2,3,4,5])
# Out:
# array('i', [2, 3, 4, 5])

# %%
ar = array.array('i', [2,3,4,5])
ar[0]
# Out:
# 2

# %%
type(ar[0])
# Out:
# int

# %%
type(ar[1:3])
# Out:
# array.array

# %%
ar[1:3]
# Out:
# array('i', [3, 4])

# %%
import numpy as np

# %%
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
np.array([[1,2,3], [4,5,6]])
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
ar = np.array([[1,2,3], [4,5,6]])

# %%
ar[0,0]
# Out:
# 1

# %%
ar[:,[0,1]]
# Out:
# array([[1, 2],
#        [4, 5]])

# %%
np.sum(ar)
# Out:
# 21

# %%
np.abs(ar)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
import pandas as pd

# %%
pd.Series([2,3,4])
# Out:
# 0    2
# 1    3
# 2    4
# dtype: int64

# %%
pd.Series([2,3,4], index=['a','b','c'])
# Out:
# a    2
# b    3
# c    4
# dtype: int64

# %%
s = pd.Series([2,3,4], index=[1,2,3])

# %%
s[1]
# Out:
# 2

# %%
s[1:3]
# Out:
# 2    3
# 3    4
# dtype: int64

# %%
s.loc[1]
# Out:
# 2

# %%
s.loc[1:3]
# Out:
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s.iloc[0]
# Out:
# 2

# %% [markdown]
# #### Type conversion

# %%
import pandas as pd
category = pd.Series(['Fashoin', 'Food', 'Footware', 'Electronics'])
sales = pd.Series(['2345','45764','5646', '3445'])
date = pd.Series(['12/01/2021','12/01/2021','12/01/2021','12/01/2021'])

# %%
category
# Out:
# 0        Fashoin
# 1           Food
# 2       Footware
# 3    Electronics
# dtype: object

# %%
category.astype('category')
# Out:
# 0        Fashoin
# 1           Food
# 2       Footware
# 3    Electronics
# dtype: category
# Categories (4, object): ['Electronics', 'Fashoin', 'Food', 'Footware']

# %%
category = category.astype('category')

# %%
sales
# Out:
# 0     2345
# 1    45764
# 2     5646
# 3     3445
# dtype: object

# %%
sales = sales.astype('int')

# %%
sales
# Out:
# 0     2345
# 1    45764
# 2     5646
# 3     3445
# dtype: int64

# %%
date
# Out:
# 0    12/01/2021
# 1    12/01/2021
# 2    12/01/2021
# 3    12/01/2021
# dtype: object

# %%
date = pd.to_datetime(date, format='%d/%m/%Y')

# %%
date
# Out:
# 0   2021-01-12
# 1   2021-01-12
# 2   2021-01-12
# 3   2021-01-12
# dtype: datetime64[ns]

# %%
pd.Series({'Fashion':2345, 'Food':2335, 'Footware':5456, 'Electronics':4673})
# Out:
# Fashion        2345
# Food           2335
# Footware       5456
# Electronics    4673
# dtype: int64

# %%
ser = pd.Series({'Fashion':2345, 'Food':2335, 'Footware':5456, 'Electronics':4673})

# %%
ser.index
# Out:
# Index(['Fashion', 'Food', 'Footware', 'Electronics'], dtype='object')

# %%
ser.values
# Out:
# array([2345, 2335, 5456, 4673])

# %%
ser['Fashion']
# Out:
# 2345

# %%
ser[0]
# Out:
# 2345

# %%
ser.loc['Fashion']
# Out:
# 2345

# %%
ser.iloc[0]
# Out:
# 2345

# %% [markdown]
# ### Dataframe

# %%
import pandas as pd

# %%
pd.DataFrame({'Category':category, 'Sales':sales, 'Date':date})
# Out:
#       Category  Sales       Date
# 0      Fashoin   2345 2021-01-12
# 1         Food  45764 2021-01-12
# 2     Footware   5646 2021-01-12
# 3  Electronics   3445 2021-01-12

# %%
data = pd.DataFrame({'Category':category, 'Sales':sales, 'Date':date})

# %%
data
# Out:
#       Category  Sales       Date
# 0      Fashoin   2345 2021-01-12
# 1         Food  45764 2021-01-12
# 2     Footware   5646 2021-01-12
# 3  Electronics   3445 2021-01-12

# %%
data.dtypes
# Out:
# Category          category
# Sales                int64
# Date        datetime64[ns]
# dtype: object

# %%
data.describe()
# Out:
#               Sales
# count      4.000000
# mean   14300.000000
# std    21020.847287
# min     2345.000000
# 25%     3170.000000
# 50%     4545.500000
# 75%    15675.500000
# max    45764.000000

# %%
data.head()
# Out:
#       Category  Sales       Date
# 0      Fashoin   2345 2021-01-12
# 1         Food  45764 2021-01-12
# 2     Footware   5646 2021-01-12
# 3  Electronics   3445 2021-01-12

# %%
data.tail()
# Out:
#       Category  Sales       Date
# 0      Fashoin   2345 2021-01-12
# 1         Food  45764 2021-01-12
# 2     Footware   5646 2021-01-12
# 3  Electronics   3445 2021-01-12

# %%
data['Category']
# Out:
# 0        Fashoin
# 1           Food
# 2       Footware
# 3    Electronics
# Name: Category, dtype: category
# Categories (4, object): ['Electronics', 'Fashoin', 'Food', 'Footware']

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data['Sales'])
# Out:
# pandas.core.series.Series

# %%
type(data.values)
# Out:
# numpy.ndarray

# %%
data.values
# Out:
# array([['Fashoin', 2345, Timestamp('2021-01-12 00:00:00')],
#        ['Food', 45764, Timestamp('2021-01-12 00:00:00')],
#        ['Footware', 5646, Timestamp('2021-01-12 00:00:00')],
#        ['Electronics', 3445, Timestamp('2021-01-12 00:00:00')]],
#       dtype=object)

# %%
data
# Out:
#       Category  Sales       Date
# 0      Fashoin   2345 2021-01-12
# 1         Food  45764 2021-01-12
# 2     Footware   5646 2021-01-12
# 3  Electronics   3445 2021-01-12

# %% [markdown]
# ## Slicing dataframes

# %%
data[['Category', 'Sales']]
# Out:
#       Category  Sales
# 0      Fashoin   2345
# 1         Food  45764
# 2     Footware   5646
# 3  Electronics   3445

# %%
data.loc[:,['Category','Sales']]
# Out:
#       Category  Sales
# 0      Fashoin   2345
# 1         Food  45764
# 2     Footware   5646
# 3  Electronics   3445

# %%
data.iloc[:,[0,1]]
# Out:
#       Category  Sales
# 0      Fashoin   2345
# 1         Food  45764
# 2     Footware   5646
# 3  Electronics   3445

# %%
data.loc[0:3,:]
# Out:
#       Category  Sales       Date
# 0      Fashoin   2345 2021-01-12
# 1         Food  45764 2021-01-12
# 2     Footware   5646 2021-01-12
# 3  Electronics   3445 2021-01-12

# %%
data.iloc[0:3,:]
# Out:
#    Category  Sales       Date
# 0   Fashoin   2345 2021-01-12
# 1      Food  45764 2021-01-12
# 2  Footware   5646 2021-01-12

# %%
data.loc[0:3,['Category','Sales']]
# Out:
#       Category  Sales
# 0      Fashoin   2345
# 1         Food  45764
# 2     Footware   5646
# 3  Electronics   3445

# %%
data.iloc[0:3,0:2]
# Out:
#    Category  Sales
# 0   Fashoin   2345
# 1      Food  45764
# 2  Footware   5646

# %%
data.iloc[0:3,[0,1]]
# Out:
#    Category  Sales
# 0   Fashoin   2345
# 1      Food  45764
# 2  Footware   5646

# %%
data
# Out:
#       Category  Sales       Date
# 0      Fashoin   2345 2021-01-12
# 1         Food  45764 2021-01-12
# 2     Footware   5646 2021-01-12
# 3  Electronics   3445 2021-01-12

# %%
data.loc[2,'Sales']
# Out:
# 5646

# %%
data.loc[2,'Sales'] = 5764

# %%
data
# Out:
#       Category  Sales       Date
# 0      Fashoin   2345 2021-01-12
# 1         Food  45764 2021-01-12
# 2     Footware   5764 2021-01-12
# 3  Electronics   3445 2021-01-12

# %%
data[data['Sales'] > 5000]
# Out:
#    Category  Sales       Date
# 1      Food  45764 2021-01-12
# 2  Footware   5764 2021-01-12

# %%
data.loc[data['Sales'] > 500,:]
# Out:
#       Category  Sales       Date
# 0      Fashoin   2345 2021-01-12
# 1         Food  45764 2021-01-12
# 2     Footware   5764 2021-01-12
# 3  Electronics   3445 2021-01-12

# %%
data.iloc[[False, True, True, False],:]
# Out:
#    Category  Sales       Date
# 1      Food  45764 2021-01-12
# 2  Footware   5764 2021-01-12

# %%
data.iloc[data['Sales'] > 5000,:]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-78-4ca4f114679d> in <module>()
# ----> 1 data.iloc[data['Sales'] > 5000,:]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1441     def _getitem_tuple(self, tup: Tuple):
#    1442
# -> 1443         self._has_valid_tuple(tup)
#    1444         try:
#    1445             return self._getitem_lowerdim(tup)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     700                 raise IndexingError("Too many indexers")
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError as err:
#     704                 raise ValueError(
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1337                 if key.index.inferred_type == "integer":
#    1338                     raise NotImplementedError(
# -> 1339                         "iLocation based boolean "
#    1340                         "indexing on an integer type "
#    1341                         "is not available"
#
# NotImplementedError: iLocation based boolean indexing on an integer type is not available

# %%
data['Sales'] > 5000
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# Name: Sales, dtype: bool

# %%
(data['Sales'] > 5000).values
# Out:
# array([False,  True,  True, False])

# %%
data.iloc[[False, True, True, False],:]
# Out:
#    Category  Sales        Date
# 1      Food  45764  12/01/2021
# 2  Footware   5646  12/01/2021

# %%
data.iloc[(data['Sales'] > 5000).values,:]
# Out:
#    Category  Sales        Date
# 1      Food  45764  12/01/2021
# 2  Footware   5646  12/01/2021

# %%
data.loc[pd.Series([True,False,True,False]), 'Category']
# Out:
# 0     Fashoin
# 2    Footware
# Name: Category, dtype: object

# %%
data.iloc[pd.Series([True,False,True,False]), 0]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-123-445e7a9a502f> in <module>()
# ----> 1 data.iloc[pd.Series([True,False,True,False]), 0]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1441     def _getitem_tuple(self, tup: Tuple):
#    1442
# -> 1443         self._has_valid_tuple(tup)
#    1444         try:
#    1445             return self._getitem_lowerdim(tup)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     700                 raise IndexingError("Too many indexers")
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError as err:
#     704                 raise ValueError(
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1337                 if key.index.inferred_type == "integer":
#    1338                     raise NotImplementedError(
# -> 1339                         "iLocation based boolean "
#    1340                         "indexing on an integer type "
#    1341                         "is not available"
#
# NotImplementedError: iLocation based boolean indexing on an integer type is not available

# %%
data.loc[data['Sales'] > 5000, 'Category']
# Out:
# 1        Food
# 2    Footware
# Name: Category, dtype: category
# Categories (4, object): ['Electronics', 'Fashoin', 'Food', 'Footware']

# %%
data['Sales'] > 5000
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# Name: Sales, dtype: bool

# %% [markdown]
# #### inserting data to dataframes

# %%
data
# Out:
#       Category  Sales       Date
# 0      Fashoin   2345 2021-01-12
# 1         Food  45764 2021-01-12
# 2     Footware   5764 2021-01-12
# 3  Electronics   3445 2021-01-12

# %%
row = {'Category':'Luxury', 'Sales':3456, 'Date':'12/01/2021'}

# %%
data.append(row, ignore_index=True)
# Out:
#       Category  Sales                 Date
# 0      Fashoin   2345  2021-01-12 00:00:00
# 1         Food  45764  2021-01-12 00:00:00
# 2     Footware   5764  2021-01-12 00:00:00
# 3  Electronics   3445  2021-01-12 00:00:00
# 4       Luxury   3456           12/01/2021

# %%
data.dtypes
# Out:
# Category          category
# Sales                int64
# Date        datetime64[ns]
# dtype: object

# %%
row1 = {'Category':['Luxury'], 'Sales':[3456], 'Date':['12/01/2021']}

# %%
row_data1 = pd.DataFrame(row1)

# %%
row2 = {'Category':'Luxury', 'Sales':3456, 'Date':'12/01/2021'}

# %%
row_data2 = pd.DataFrame(row2, index=[4])

# %%
row_data2
# Out:
#   Category  Sales        Date
# 4   Luxury   3456  12/01/2021

# %%
row_data1
# Out:
#   Category  Sales        Date
# 0   Luxury   3456  12/01/2021

# %%
data.append(row_data1)
# Out:
#       Category  Sales                 Date
# 0      Fashoin   2345  2021-01-12 00:00:00
# 1         Food  45764  2021-01-12 00:00:00
# 2     Footware   5764  2021-01-12 00:00:00
# 3  Electronics   3445  2021-01-12 00:00:00
# 0       Luxury   3456           12/01/2021

# %%
data.append(row_data2)
# Out:
#       Category  Sales                 Date
# 0      Fashoin   2345  2021-01-12 00:00:00
# 1         Food  45764  2021-01-12 00:00:00
# 2     Footware   5764  2021-01-12 00:00:00
# 3  Electronics   3445  2021-01-12 00:00:00
# 4       Luxury   3456           12/01/2021

# %%
# dataframes -> slice -> insert data -> UPDATE DATA

# %% [markdown]
# #### Update data

# %%
whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# category   Series       0        Fashoin\n1      <...>oin', 'Food', 'Footware']
# data       DataFrame          Category  Sales    <...>tronics   3445 2021-01-12
# date       Series       0   2021-01-12\n1   2021-<...>12\ndtype: datetime64[ns]
# pd         module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# sales      Series       0     2345\n1    45764\n2<...>n3     3445\ndtype: int64

# %%
who
# Out:
# category	 data	 date	 pd	 sales

# %%
data
# Out:
#       Category  Sales       Date
# 0      Fashoin   2345 2021-01-12
# 1         Food  45764 2021-01-12
# 2     Footware   5646 2021-01-12
# 3  Electronics   3445 2021-01-12

# %%
data.loc[1,'Sales']
# Out:
# 45764

# %%
data.loc[1,'Sales'] = 5764

# %%
data
# Out:
#       Category  Sales       Date
# 0      Fashoin   2345 2021-01-12
# 1         Food   5764 2021-01-12
# 2     Footware   5646 2021-01-12
# 3  Electronics   3445 2021-01-12

# %%
data.iloc[2,1]
# Out:
# 5646

# %%
data.iloc[2,1] = 5567

# %%
data
# Out:
#       Category  Sales       Date
# 0      Fashoin   2345 2021-01-12
# 1         Food   5764 2021-01-12
# 2     Footware   5567 2021-01-12
# 3  Electronics   3445 2021-01-12

# %%
data.loc[data['Category'] == 'Fashoin','Sales']
# Out:
# 0    2345
# Name: Sales, dtype: int64

# %%
data.loc[data['Category'] == 'Fashoin','Sales'] = 3456

# %%
data
# Out:
#       Category  Sales       Date
# 0      Fashoin   3456 2021-01-12
# 1         Food   5764 2021-01-12
# 2     Footware   5567 2021-01-12
# 3  Electronics   3445 2021-01-12

# %%
data['Location'] = 'Bangalore'

# %%
data
# Out:
#       Category  Sales       Date   Location
# 0      Fashoin   3456 2021-01-12  Bangalore
# 1         Food   5764 2021-01-12  Bangalore
# 2     Footware   5567 2021-01-12  Bangalore
# 3  Electronics   3445 2021-01-12  Bangalore

# %%
data['Distributor Location'] = ['Bangalore', 'Hyderabad', 'Mumbai', 'Chennai']

# %%
data
# Out:
#       Category  Sales       Date   Location Distributor Location
# 0      Fashoin   3456 2021-01-12  Bangalore            Bangalore
# 1         Food   5764 2021-01-12  Bangalore            Hyderabad
# 2     Footware   5567 2021-01-12  Bangalore               Mumbai
# 3  Electronics   3445 2021-01-12  Bangalore              Chennai

# %%
data1 = data[['Category', 'Sales', 'Date', 'Distributor Location']].copy()

# %%
data1
# Out:
#       Category  Sales       Date Distributor Location
# 0      Fashoin   3456 2021-01-12            Bangalore
# 1         Food   5764 2021-01-12            Hyderabad
# 2     Footware   5567 2021-01-12               Mumbai
# 3  Electronics   3445 2021-01-12              Chennai

# %%
data2 = data.drop(columns=['Location'])

# %%
data
# Out:
#       Category  Sales       Date   Location Distributor Location
# 0      Fashoin   3456 2021-01-12  Bangalore            Bangalore
# 1         Food   5764 2021-01-12  Bangalore            Hyderabad
# 2     Footware   5567 2021-01-12  Bangalore               Mumbai
# 3  Electronics   3445 2021-01-12  Bangalore              Chennai

# %%
data2
# Out:
#       Category  Sales       Date Distributor Location
# 0      Fashoin   3456 2021-01-12            Bangalore
# 1         Food   5764 2021-01-12            Hyderabad
# 2     Footware   5567 2021-01-12               Mumbai
# 3  Electronics   3445 2021-01-12              Chennai

# %%
data3 = data.iloc[:3,:]

# %%
data3
# Out:
#    Category  Sales       Date   Location Distributor Location
# 0   Fashoin   3456 2021-01-12  Bangalore            Bangalore
# 1      Food   5764 2021-01-12  Bangalore            Hyderabad
# 2  Footware   5567 2021-01-12  Bangalore               Mumbai

# %%
del data3['Location']

# %%
data3
# Out:
#    Category  Sales       Date Distributor Location
# 0   Fashoin   3456 2021-01-12            Bangalore
# 1      Food   5764 2021-01-12            Hyderabad
# 2  Footware   5567 2021-01-12               Mumbai

# %%
# dataframes -> slicing -> insert -> update -> delete
